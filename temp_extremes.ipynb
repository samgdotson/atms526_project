# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import pyextremes

# %%
df = pd.read_csv('nrel_psm_data/BraidwoodGenerationStation_Temperature_2007_2020.csv', index_col='time', 
                 parse_dates=True)
df.head()
# Out:
#                      Temp_BraidwoodGenerationStation
# time
# 2007-01-01 00:00:00                              3.0
# 2007-01-01 00:30:00                              2.0
# 2007-01-01 01:00:00                              2.0
# 2007-01-01 01:30:00                              1.0
# 2007-01-01 02:00:00                              1.0

# %%
df.plot()
# Out:
# <AxesSubplot:xlabel='time'>

# %%
df_ex = df[df.Temp_BraidwoodGenerationStation > 32]

# %%
fig, ax = plt.subplots()

ax.scatter(df_ex.index, df_ex.Temp_BraidwoodGenerationStation)

# %%
df_ex.groupby(df_ex.index.year).count().plot()
# Out:
# <AxesSubplot:xlabel='time'>
